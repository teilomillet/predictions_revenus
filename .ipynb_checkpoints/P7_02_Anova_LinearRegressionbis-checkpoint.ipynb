# %% [markdown]
# # Mission 4
# Pour cette mission 4, nous chercherons à expliquer le revenu des individus en fonction de plusieurs variables explicatives : le pays de l'individu, l'indice de Gini de ce pays, la classe de revenus des parents, etc.
#
# Appliquez une ANOVA sur vos données, en n’incluant comme variable explicative que le pays de l’individu. Analysez la performance du modèle.
#
#
# Appliquez une régression linéaire sur vos données, en incluant comme variables explicatives uniquement le revenu moyen du pays de l’individu et l’indice de Gini du pays de l’individu. Quel est le pourcentage de variance expliquée par votre modèle ?
#
# - Pour chacune des régressions suivantes, vous testerez 2 version : l'une en exprimant le revenu moyen du pays et les revenus (parents & enfants) en logarithme (ln), l'autre en les laissant tels quels. Vous choisirez la version la plus performante pour répondre aux question.
#
#
#
# Selon ce modèle, donnez la décomposition de variance totale expliquée par :
#
# le pays de naissance (ie. le revenu moyen et l’indice de Gini) ;
# les autres facteurs non considérés dans le modèle (efforts, chance, etc.).
# Améliorez le modèle précédent en incluant maintenant la classe de revenu des parents. Quel est le pourcentage de variance expliquée par ce nouveau modèle ?

# %% [markdown]
# ## Importation des librairies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## Importation des données

# %%
# Données créées dans le précedent notebook
data = pd.read_csv("/Users/teilo/Desktop/OC - Projet 7/predictions_revenus/dataframe.csv")
data = data.drop(columns='Unnamed: 0')
data
# Out:
#                  Name  c_i_child      y_child        Gj        pj  c_i_parent  \
# 0             Albania          1    728.89795  0.304624  0.815874         1.0
# 1             Albania          1    728.89795  0.304624  0.815874         1.0
# 2             Albania          1    728.89795  0.304624  0.815874         1.0
# 3             Albania          1    728.89795  0.304624  0.815874         1.0
# 4             Albania          1    728.89795  0.304624  0.815874         1.0
# ...               ...        ...          ...       ...       ...         ...
# 3249995  South Africa        100  82408.55000  0.669779  0.677000       100.0
# 3249996  South Africa        100  82408.55000  0.669779  0.677000       100.0
# 3249997  South Africa        100  82408.55000  0.669779  0.677000       100.0
# 3249998  South Africa        100  82408.55000  0.669779  0.677000       100.0
# 3249999  South Africa        100  82408.55000  0.669779  0.677000       100.0
#
#              rev_moy  ln_y_child  ln_rev_moy
# 0        2994.829902    6.591534    8.004643
# 1        2994.829902    6.591534    8.004643
# 2        2994.829902    6.591534    8.004643
# 3        2994.829902    6.591534    8.004643
# 4        2994.829902    6.591534    8.004643
# ...              ...         ...         ...
# 3249995  5617.904880   11.319444    8.633714
# 3249996  5617.904880   11.319444    8.633714
# 3249997  5617.904880   11.319444    8.633714
# 3249998  5617.904880   11.319444    8.633714
# 3249999  5617.904880   11.319444    8.633714
#
# [3250000 rows x 9 columns]

# %% [markdown]
# ## Analyse de la variance (ANOVA)

# %%
def eta_squared(x,y):
    moyenne_y = y.mean()
    classes = []
    for classe in x.unique():
        yi_classe = y[x==classe]
        classes.append({'ni': len(yi_classe),
                        'moyenne_classe': yi_classe.mean()})
    SCT = sum([(yj-moyenne_y)**2 for yj in y])
    SCE = sum([c['ni']*(c['moyenne_classe']-moyenne_y)**2 for c in classes])
    return SCE/SCT

# %% [markdown]
# #### 1. Analyse par pays

# %%
# Selection des pays à analyser
countries = data.loc[(data['Name'] == 'France') | (data['Name'] == 'Brazil') | 
            (data['Name'] == 'Canada') | (data['Name'] == 'Bangladesh') |
            (data['Name'] == 'South Africa') | (data['Name'] == 'Slovenia')]

plt.figure(figsize=(12,10))
sns_plot = sns.boxplot(y='y_child', x='Name', data=countries,showfliers=False)
sns.set_theme()
plt.xlabel("Pays")
plt.ylabel("Revenus")
plt.show()

print("Eta^2 =", eta_squared(countries['Name'], countries['y_child']))
# Out:
# Eta^2 = 0.3515266280113387

# %% [markdown]
# On remarque qu'il existe une grande disparité entre les différents pays.

# %%
# Ordinary least squared
model = ols('y_child ~ Name', data = countries).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
# Out:
#                 sum_sq        df             F  PR(>F)
# Name      1.921300e+13       5.0  32524.351438     0.0
# Residual  3.544288e+13  299994.0           NaN     NaN

# %% [markdown]
# ## Regression linéaire

# %% [markdown]
# #### a. revenu moyen + indice de Gini

# %%
# Test 1
countries1 = countries[['Name', 'rev_moy', 'y_child', 'c_i_child', 'Gj', 'c_i_parent']]
countries1
# Out:
#                  Name      rev_moy      y_child  c_i_child        Gj  \
# 150000     Bangladesh   998.692409    276.93503          1  0.316444
# 150001     Bangladesh   998.692409    276.93503          1  0.316444
# 150002     Bangladesh   998.692409    276.93503          1  0.316444
# 150003     Bangladesh   998.692409    276.93503          1  0.316444
# 150004     Bangladesh   998.692409    276.93503          1  0.316444
# ...               ...          ...          ...        ...       ...
# 3249995  South Africa  5617.904880  82408.55000        100  0.669779
# 3249996  South Africa  5617.904880  82408.55000        100  0.669779
# 3249997  South Africa  5617.904880  82408.55000        100  0.669779
# 3249998  South Africa  5617.904880  82408.55000        100  0.669779
# 3249999  South Africa  5617.904880  82408.55000        100  0.669779
#
#          c_i_parent
# 150000          1.0
# 150001          1.0
# 150002          1.0
# 150003          1.0
# 150004          1.0
# ...             ...
# 3249995       100.0
# 3249996       100.0
# 3249997       100.0
# 3249998       100.0
# 3249999       100.0
#
# [300000 rows x 6 columns]

# %%
# X et Y
X = countries1[['rev_moy', 'Gj']]
Y = countries1['y_child']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y)

# %%
# Creation du model
model = linear_model.LinearRegression()

# %%
# Entrainement du model
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Prediction
y_pred = model.predict(x_test)

# %%
# Performance du model
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean Squared Error: %.3f'
     % mean_squared_error(y_test, y_pred))
print('Coefficient de determination (R^2): %.3f'
     % r2_score(y_test, y_pred))
# Out:
# Coefficients: [ 0.9994708  78.75541052]
# Intercept: -16.81934128985813
# Mean Squared Error: 115388302.801
# Coefficient de determination (R^2): 0.359

# %%
# Y = coefficient1*(rev_moy) + coefficient2*(Gj) + Intercept

# %%
# Result de Mean Absolute Error
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))

# Resutat de Mean Squared Error
print("Mean Squared Error", metrics.mean_squared_error(y_test, y_pred))

# Resultat de MSE^2
print("MSE^2:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 5666.213132479142
# Mean Squared Error 115388302.80138819
# MSE^2: 10741.894749130071

# %% [markdown]
# Les résultats obtenus lors de cette regression linéaire ne sont pas satisfaisants. Le MSE à une grande valeur ce qui signifie que le modele ne permet pas de determiner correctement le revenu de l'enfant.

# %%
sns.regplot(y_test, y_pred, marker='+')
# Out:
# /Users/teilo/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='y_child'>

# %%
# Ordinary least squared
model = ols('y_child ~ rev_moy+Gj', data = countries1).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
# Out:
#                 sum_sq        df             F  PR(>F)
# rev_moy   1.624258e+13       1.0  1.374811e+05     0.0
# Gj        1.040772e-12       1.0  8.809339e-21     1.0
# Residual  3.544288e+13  299997.0           NaN     NaN

# %% [markdown]
# #### b. Revenu moyen (logarithmique) et indice de Gini

# %%
#Test 2
countries2 = countries[['Name', 'ln_rev_moy', 'ln_y_child', 'c_i_child', 'Gj', 'c_i_parent']]
countries2
# Out:
#                  Name  ln_rev_moy  ln_y_child  c_i_child        Gj  c_i_parent
# 150000     Bangladesh    6.906447    5.623783          1  0.316444         1.0
# 150001     Bangladesh    6.906447    5.623783          1  0.316444         1.0
# 150002     Bangladesh    6.906447    5.623783          1  0.316444         1.0
# 150003     Bangladesh    6.906447    5.623783          1  0.316444         1.0
# 150004     Bangladesh    6.906447    5.623783          1  0.316444         1.0
# ...               ...         ...         ...        ...       ...         ...
# 3249995  South Africa    8.633714   11.319444        100  0.669779       100.0
# 3249996  South Africa    8.633714   11.319444        100  0.669779       100.0
# 3249997  South Africa    8.633714   11.319444        100  0.669779       100.0
# 3249998  South Africa    8.633714   11.319444        100  0.669779       100.0
# 3249999  South Africa    8.633714   11.319444        100  0.669779       100.0
#
# [300000 rows x 6 columns]

# %%
# X et Y
X = countries2[['ln_rev_moy', 'Gj']]
Y = countries2['ln_y_child']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y)

# %%
# Creation du model
model = linear_model.LinearRegression()

# %%
# Entrainement du model
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Prediction
y_pred = model.predict(x_test)

# %%
# Performance du model
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean Squared Error: %.3f'
     % mean_squared_error(y_test, y_pred))
print('Coefficient de determination (R^2): %.3f'
     % r2_score(y_test, y_pred))
# Out:
# Coefficients: [ 0.98807382 -1.89978548]
# Intercept: 0.5209322774910454
# Mean Squared Error: 0.725
# Coefficient de determination (R^2): 0.636

# %%
# Y = coefficient1*(ln_rev_moy) + coefficient2*(Gj) + Intercept

# %%
# Result de Mean Absolute Error
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))

# Resutat de Mean Squared Error
print("Mean Squared Error", metrics.mean_squared_error(y_test, y_pred))

# Resultat de MSE^2
print("MSE^2:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.5987600387942958
# Mean Squared Error 0.725433115358099
# MSE^2: 0.8517236144184913

# %% [markdown]
# Les résultats obtenus lors de cette regression linéaire sont meilleurs que ceux obtenus lors de la précèdente. Nous choisirons donc de continuer avec ce modele.

# %%
sns.regplot(y_test, y_pred, marker='+')
# Out:
# /Users/teilo/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ln_y_child'>

# %%
# Ordinary least squared
model = ols('ln_y_child ~ ln_rev_moy+Gj', data = countries2).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
# Out:
#                    sum_sq        df              F  PR(>F)
# ln_rev_moy  315489.569830       1.0  437581.858319     0.0
# Gj           23776.598328       1.0   32977.977962     0.0
# Residual    216293.072212  299997.0            NaN     NaN

# %% [markdown]
# #### c. Ajout de la classe des parents

# %%
# X et Y
X = countries2[['ln_rev_moy', 'Gj', 'c_i_parent']]
Y = countries2['ln_y_child']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y)

# %%
# Creation du model
model = linear_model.LinearRegression()

# %%
# Entrainement du model
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Prediction
y_pred = model.predict(x_test)

# %%
# Performance du model
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean Squared Error: %.3f'
     % mean_squared_error(y_test, y_pred))
print('Coefficient de determination (R^2): %.3f'
     % r2_score(y_test, y_pred))
# Out:
# Coefficients: [ 0.98767266 -1.90103648  0.01164921]
# Intercept: -0.06515969059943671
# Mean Squared Error: 0.601
# Coefficient de determination (R^2): 0.699

# %%
# Y = coefficient1*(ln_rev_moy) + coefficient2*(Gj) + coefficient3*(c_i_parent) + Intercept

# %%
# Result de Mean Absolute Error
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))

# Resutat de Mean Squared Error
print("Mean Squared Error", metrics.mean_squared_error(y_test, y_pred))

# Resultat de MSE^2
print("MSE^2:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.5620363773615344
# Mean Squared Error 0.6010869032425066
# MSE^2: 0.775297944820252

# %% [markdown]
# On remarque que cette regression linéaire est plus performante que les 2 précèdentes.

# %% [markdown]
# Le coefficient de Gini est négative, ce qui signifie que le fait de vivre dans un pays inégalitaire défavorise les personnes habitant le pays.

# %%
# Ordinary least squared
model = ols('ln_y_child ~ Name+c_i_parent', data = countries2).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
# Out:
#                    sum_sq        df              F  PR(>F)
# Name        384251.736997       5.0  126873.322887     0.0
# c_i_parent   33913.235814       1.0   55987.839524     0.0
# Residual    181713.269131  299993.0            NaN     NaN
