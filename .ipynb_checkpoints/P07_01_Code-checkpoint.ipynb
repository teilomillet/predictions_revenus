# %% [markdown]
# # Effectuez une prédiction de revenus
#
# ## Mission 1
# Résumez les données utilisées :
# - Année(s) des données utilisées
# - Nombre de pays présents
# - Population couverte par l'analyse (en termes de pourcentage de la population mondiale)
# Les données de la world income distribution présentent pour chaque pays les quantiles de la
# distribution des revenus de leur population respective.
# - De quel type de quantiles s'agit-il (quartiles, déciles, etc.) ?
# - Échantillonner une population en utilisant des quantiles est-il selon vous une bonne méthode? Pourquoi ?

# %% [markdown]
# ## Importation des données et des bibliothèques

# %%
# Importation des bibliothèques
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importation des données
data = pd.read_csv('/Users/teilo/Desktop/OC - Projet 7/predictions_revenus/Données/data-projet7.csv')
data
# Out:
#       country  year_survey  quantile  nb_quantiles     income     gdpppp
# 0         ALB         2008         1           100  728,89795       7297
# 1         ALB         2008         2           100  916,66235       7297
# 2         ALB         2008         3           100   1010,916       7297
# 3         ALB         2008         4           100  1086,9078       7297
# 4         ALB         2008         5           100  1132,6997       7297
# ...       ...          ...       ...           ...        ...        ...
# 11594     COD         2008        96           100   810,6233  303,19305
# 11595     COD         2008        97           100   911,7834  303,19305
# 11596     COD         2008        98           100  1057,8074  303,19305
# 11597     COD         2008        99           100  1286,6029  303,19305
# 11598     COD         2008       100           100  2243,1226  303,19305
#
# [11599 rows x 6 columns]

# %% [markdown]
# ## Nettoyage des données

# %%
data = data.rename(columns= {
    'country': 'Country',
    'year_survey': 'Year',
    'quantile': 'Quantile',
    'income': 'Income',
    'gdpppp': 'GDP'
})
data
# Out:
#       Country  Year  Quantile  nb_quantiles     Income        GDP
# 0         ALB  2008         1           100  728,89795       7297
# 1         ALB  2008         2           100  916,66235       7297
# 2         ALB  2008         3           100   1010,916       7297
# 3         ALB  2008         4           100  1086,9078       7297
# 4         ALB  2008         5           100  1132,6997       7297
# ...       ...   ...       ...           ...        ...        ...
# 11594     COD  2008        96           100   810,6233  303,19305
# 11595     COD  2008        97           100   911,7834  303,19305
# 11596     COD  2008        98           100  1057,8074  303,19305
# 11597     COD  2008        99           100  1286,6029  303,19305
# 11598     COD  2008       100           100  2243,1226  303,19305
#
# [11599 rows x 6 columns]

# %%
data.describe()
# Out:
#                Year      Quantile  nb_quantiles
# count  11599.000000  11599.000000       11599.0
# mean    2007.982757     50.500819         100.0
# std        0.909633     28.868424           0.0
# min     2004.000000      1.000000         100.0
# 25%     2008.000000     25.500000         100.0
# 50%     2008.000000     51.000000         100.0
# 75%     2008.000000     75.500000         100.0
# max     2011.000000    100.000000         100.0

# %% [markdown]
# On remarque que les années prises en compte dans ces données vont de 2004 à 2011. Avec une année moyenne estimé à 2008.
#
# On peut supprimer la colonne 'nb_quantiles' car les données sont toujours 100.

# %%
data = data.drop(columns='nb_quantiles')
data
# Out:
#       Country  Year  Quantile     Income        GDP
# 0         ALB  2008         1  728,89795       7297
# 1         ALB  2008         2  916,66235       7297
# 2         ALB  2008         3   1010,916       7297
# 3         ALB  2008         4  1086,9078       7297
# 4         ALB  2008         5  1132,6997       7297
# ...       ...   ...       ...        ...        ...
# 11594     COD  2008        96   810,6233  303,19305
# 11595     COD  2008        97   911,7834  303,19305
# 11596     COD  2008        98  1057,8074  303,19305
# 11597     COD  2008        99  1286,6029  303,19305
# 11598     COD  2008       100  2243,1226  303,19305
#
# [11599 rows x 5 columns]

# %%
mean = data.groupby('Country').mean()
mean
# Out:
#            Year  Quantile
# Country
# ALB      2008.0      50.5
# ARG      2008.0      50.5
# ARM      2008.0      50.5
# AUT      2008.0      50.5
# AZE      2008.0      50.5
# ...         ...       ...
# VEN      2006.0      50.5
# VNM      2006.0      50.5
# XKX      2008.0      50.5
# YEM      2008.0      50.5
# ZAF      2008.0      50.5
#
# [116 rows x 2 columns]

# %% [markdown]
# 116 pays sont représentés dans ce jeu de données.

# %% [markdown]
# ### Correspondance des données avec la population
# Nous selectionnons les données de la population de 2008 (année moyenne) afin de pouvoir calculer la proportion de chaque pays sur le total de la population d'une année.

# %% [markdown]
# ### Calcul de la contribution de chaque pays à la population mondiale

# %%
population = pd.read_csv("/Users/teilo/Desktop/OC - Projet 7/predictions_revenus/Données/population1.csv", on_bad_lines='skip')
population = population['Country Name;Country Code;2008;'].str.split(";", n=3, expand=True)
population = population.rename(columns={0:"Name", 1:'Country', 2:'Population'})
population = population.drop(columns=3)
population
# Out:
#                             Name Country Population
# 0                          Aruba     ABW     101362
# 1    Africa Eastern and Southern     AFE  491173160
# 2                    Afghanistan     AFG   27722281
# 3     Africa Western and Central     AFW  331772330
# 4                         Angola     AGO   21695636
# ..                           ...     ...        ...
# 248                        Samoa     WSM     183270
# 249                       Kosovo     XKX    1747383
# 250                 South Africa     ZAF   49779472
# 251                       Zambia     ZMB   12848531
# 252                     Zimbabwe     ZWE   12379553
#
# [253 rows x 3 columns]

# %%
data = data.merge(population, how='left', on='Country')
data
# Out:
#       Country  Year  Quantile     Income        GDP     Name Population
# 0         ALB  2008         1  728,89795       7297  Albania    2947314
# 1         ALB  2008         2  916,66235       7297  Albania    2947314
# 2         ALB  2008         3   1010,916       7297  Albania    2947314
# 3         ALB  2008         4  1086,9078       7297  Albania    2947314
# 4         ALB  2008         5  1132,6997       7297  Albania    2947314
# ...       ...   ...       ...        ...        ...      ...        ...
# 11594     COD  2008        96   810,6233  303,19305      NaN        NaN
# 11595     COD  2008        97   911,7834  303,19305      NaN        NaN
# 11596     COD  2008        98  1057,8074  303,19305      NaN        NaN
# 11597     COD  2008        99  1286,6029  303,19305      NaN        NaN
# 11598     COD  2008       100  2243,1226  303,19305      NaN        NaN
#
# [11599 rows x 7 columns]

# %%
# Ajout des valeurs qui n'ont merge
# Congo
data.loc[data['Country'] == 'COD', 'Name'] = 'Congo'
data.loc[data['Country'] == 'COD', 'Population'] = 60411195

# Yemen
data.loc[data['Country'] == 'YEM', 'Name'] = 'Yemen'
data.loc[data['Country'] == 'YEM', 'Population'] = 21892149

# Venezuela
data.loc[data['Country'] == 'VEN', 'Name'] = 'Venezuela'
data.loc[data['Country'] == 'VEN', 'Population'] = 27635827

# Corée
data.loc[data['Country'] == 'KOR', 'Name'] = 'Korea'
data.loc[data['Country'] == 'KOR', 'Population'] = 49054708

# Iran
data.loc[data['Country'] == 'IRN', 'Name'] = 'Iran'
data.loc[data['Country'] == 'IRN', 'Population'] = 72120608

# Egypt
data.loc[data['Country'] == 'EGY', 'Name'] = 'Egypt'
data.loc[data['Country'] == 'EGY', 'Population'] = 79636081

# %%
null_data = data[data.isnull().any(axis=1)]
null_data = null_data.sort_values('GDP')
print(null_data)
# Out:
#       Country  Year  Quantile     Income    GDP                Name Population
# 10399     TWN  2008         1    3477,18  25342                 NaN        NaN
# 10471     TWN  2008        73  18624,781  25342                 NaN        NaN
# 10470     TWN  2008        72  18307,312  25342                 NaN        NaN
# 10469     TWN  2008        71  18002,643  25342                 NaN        NaN
# 10468     TWN  2008        70  17704,814  25342                 NaN        NaN
# ...       ...   ...       ...        ...    ...                 ...        ...
# 11294     PSE  2009        96  2763,8848    NaN  West Bank and Gaza    3591977
# 11295     PSE  2009        97  3077,8333    NaN  West Bank and Gaza    3591977
# 11296     PSE  2009        98  3449,2224    NaN  West Bank and Gaza    3591977
# 11297     PSE  2009        99   4165,997    NaN  West Bank and Gaza    3591977
# 11298     PSE  2009       100  6343,8755    NaN  West Bank and Gaza    3591977
#
# [300 rows x 7 columns]

# %%
# Suppression de Taiwan compris dans la Chine par les données de la population de World Bank Data
data = data.set_index('Country')
data = data.drop('TWN')
data
# Out:
#          Year  Quantile     Income        GDP     Name Population
# Country
# ALB      2008         1  728,89795       7297  Albania    2947314
# ALB      2008         2  916,66235       7297  Albania    2947314
# ALB      2008         3   1010,916       7297  Albania    2947314
# ALB      2008         4  1086,9078       7297  Albania    2947314
# ALB      2008         5  1132,6997       7297  Albania    2947314
# ...       ...       ...        ...        ...      ...        ...
# COD      2008        96   810,6233  303,19305    Congo   60411195
# COD      2008        97   911,7834  303,19305    Congo   60411195
# COD      2008        98  1057,8074  303,19305    Congo   60411195
# COD      2008        99  1286,6029  303,19305    Congo   60411195
# COD      2008       100  2243,1226  303,19305    Congo   60411195
#
# [11499 rows x 6 columns]

# %%
# Données en string donc changement des ',' en '.' pour changer en valeur
data['Income'] = data['Income'].str.replace(',', '.')
data['GDP'] = data['GDP'].str.replace(',', '.')

# %%
# Changement des données en valeur int et float.
data['Population'] = data['Population'].astype(int)
data['Income'] = data['Income'].astype(float)
data['GDP'] = data['GDP'].astype(float)
data['Quantile'] = data['Quantile'].astype(int)

# %%
# Calcul du % de la population d'un pays par rapport à la population mondiale
# Division par nb_quartiles(100) la somme de la population
pop_total = data['Population'].sum()/100
data['%_pop_total'] = data['Population']/pop_total*100
print(f"""Population du Monde en 2008: {pop_total:,}""")
print(f"""Ces données couvrent {data['%_pop_total'].sum()/100}% de la population mondiale""")
# Out:
# Population du Monde en 2008: 6,180,792,961.69
# Ces données couvrent 100.00000000000001% de la population mondiale

# %% [markdown]
# #### Réponse à la mission 1
# Le type de quantiles utilisité pour cette analyse est le "Centiles" car les données sont divisé en 100 quantiles.

# %%
data = data.reset_index()

# %%
for cat in data["Country"].unique():
    subset = data[data.Country == cat]
    print("PAYS :",cat)
    print("Moyenne:",subset['Income'].mean())
    print("Medianne:",subset['Income'].median())
    print("Minimal:", subset['Income'].min())
    print("Maximal:", subset['Income'].max())
    print()
    subset["Income"].hist() 
    plt.show()
# Out:
# PAYS : ALB
# Moyenne: 2994.829902
# Medianne: 2504.8456
# Minimal: 728.89795
# Maximal: 17754.324
# PAYS : ARG
# Moyenne: 5847.8846537
# Medianne: 4184.390600000001
# Minimal: 254.08942
# Maximal: 43669.242
# PAYS : ARM
# Moyenne: 1628.3827849
# Medianne: 1437.3175
# Minimal: 366.6178
# Maximal: 6566.159
# PAYS : AUT
# Moyenne: 16637.600204
# Medianne: 14656.426
# Minimal: 2958.0764
# Maximal: 72216.68
# PAYS : AZE
# Moyenne: 2357.4290230000006
# Medianne: 1952.24955
# Minimal: 397.53983
# Maximal: 12023.727
# PAYS : BEL
# Moyenne: 15024.614175999997
# Medianne: 13177.868
# Minimal: 2421.9417
# Maximal: 83104.47
# PAYS : BFA
# Moyenne: 917.9526581999999
# Medianne: 664.7728500000001
# Minimal: 138.40517
# Maximal: 7693.4043
# PAYS : BGD
# Moyenne: 998.6924091000002
# Medianne: 799.524365
# Minimal: 276.93503
# Maximal: 5949.081
# PAYS : BGR
# Moyenne: 4984.978558600001
# Medianne: 4140.76285
# Minimal: 271.0931
# Maximal: 28613.781
# PAYS : BIH
# Moyenne: 6334.687310999999
# Medianne: 5114.79765
# Minimal: 808.3991
# Maximal: 31251.586
# PAYS : BLR
# Moyenne: 3921.163534399998
# Medianne: 3515.49735
# Minimal: 913.44214
# Maximal: 13135.336
# PAYS : BOL
# Moyenne: 3016.2638432900003
# Medianne: 1777.67525
# Minimal: 20.584948
# Maximal: 43786.92
# PAYS : BRA
# Moyenne: 4807.484593800001
# Medianne: 2803.8358
# Minimal: 144.02846
# Maximal: 59115.98
# PAYS : BTN
# Moyenne: 1515.9290608
# Medianne: 1152.09295
# Minimal: 254.01678
# Maximal: 8999.639
# PAYS : CAF
# Moyenne: 811.2999005599999
# Medianne: 446.27648
# Minimal: 40.92813
# Maximal: 14472.948
# PAYS : CAN
# Moyenne: 23739.640518100005
# Medianne: 20333.6045
# Minimal: 122.42481
# Maximal: 133454.84
# PAYS : CHL
# Moyenne: 7051.6099664
# Medianne: 3996.91995
# Minimal: 231.63004
# Maximal: 96583.21
# PAYS : CHN
# Moyenne: 2522.75872648
# Medianne: 1631.7195000000002
# Minimal: 16.719418
# Maximal: 17091.404
# PAYS : CIV
# Moyenne: 399.83520418999996
# Medianne: 292.558715
# Minimal: 34.555264
# Maximal: 2814.3389
# PAYS : CMR
# Moyenne: 1794.4939640999999
# Medianne: 1330.7845
# Minimal: 396.4525
# Maximal: 12239.05
# PAYS : COL
# Moyenne: 3547.0052755
# Medianne: 1942.8636999999999
# Minimal: 62.60506
# Maximal: 50671.125
# PAYS : CRI
# Moyenne: 5580.386556299999
# Medianne: 3441.4751
# Minimal: 275.6539
# Maximal: 57881.08
# PAYS : CYP
# Moyenne: 17345.38746300001
# Medianne: 15176.84
# Minimal: 4406.3354
# Maximal: 98480.56
# PAYS : CZE
# Moyenne: 8235.293410999999
# Medianne: 7335.3867
# Minimal: 1586.2471
# Maximal: 37063.617
# PAYS : DEU
# Moyenne: 18061.718142
# Medianne: 15271.6285
# Minimal: 2205.0122
# Maximal: 103661.98
# PAYS : DNK
# Moyenne: 17043.146491
# Medianne: 14970.8325
# Minimal: 1960.654
# Maximal: 96152.695
# PAYS : DOM
# Moyenne: 3558.4021047
# Medianne: 2207.51635
# Minimal: 234.87552
# Maximal: 42247.625
# PAYS : ECU
# Moyenne: 3383.7410011499996
# Medianne: 2090.09995
# Minimal: 99.078545
# Maximal: 36537.95
# PAYS : EGY
# Moyenne: 1969.5773988000008
# Medianne: 1558.51795
# Minimal: 458.9584
# Maximal: 14783.105
# PAYS : ESP
# Moyenne: 13116.992909600003
# Medianne: 11579.4535
# Minimal: 796.71906
# Maximal: 51302.695
# PAYS : EST
# Moyenne: 7702.062592999999
# Medianne: 6586.80125
# Minimal: 959.5601
# Maximal: 32201.139
# PAYS : FIN
# Moyenne: 16306.330495000002
# Medianne: 14186.200499999999
# Minimal: 3248.9075
# Maximal: 82762.27
# PAYS : FJI
# Moyenne: 2098.7308823
# Medianne: 1452.7935
# Minimal: 308.17334
# Maximal: 22161.59
# PAYS : FRA
# Moyenne: 18309.407545000005
# Medianne: 15092.115
# Minimal: 2958.304
# Maximal: 122775.164
# PAYS : GBR
# Moyenne: 21709.604470000006
# Medianne: 17964.5645
# Minimal: 1416.5803
# Maximal: 141565.23
# PAYS : GEO
# Moyenne: 1363.7586064600002
# Medianne: 1080.81275
# Minimal: 97.541626
# Maximal: 8057.186
# PAYS : GHA
# Moyenne: 736.60252913
# Medianne: 536.44713
# Minimal: 63.157047
# Maximal: 5745.637
# PAYS : GIN
# Moyenne: 696.0120132999999
# Medianne: 510.81283499999995
# Minimal: 93.35419
# Maximal: 4375.0903
# PAYS : GRC
# Moyenne: 11727.274287400001
# Medianne: 10147.0405
# Minimal: 1002.84344
# Maximal: 63745.08
# PAYS : GTM
# Moyenne: 2142.47475251
# Medianne: 1172.8265000000001
# Minimal: 38.463615
# Maximal: 39799.406
# PAYS : HND
# Moyenne: 3296.26841943
# Medianne: 1659.1041500000001
# Minimal: 50.166843
# Maximal: 56265.7
# PAYS : HRV
# Moyenne: 7716.46579
# Medianne: 6546.156199999999
# Minimal: 1355.1073
# Maximal: 37576.465
# PAYS : HUN
# Moyenne: 6101.341229000003
# Medianne: 5451.5632000000005
# Minimal: 1211.3455
# Maximal: 26059.27
# PAYS : IDN
# Moyenne: 1334.6182974
# Medianne: 989.21625
# Minimal: 306.27643
# Maximal: 11594.235
# PAYS : IND
# Moyenne: 924.2694587999998
# Medianne: 708.85145
# Minimal: 247.83873
# Maximal: 6176.5205
# PAYS : IRL
# Moyenne: 17710.735837999997
# Medianne: 14946.4485
# Minimal: 2819.135
# Maximal: 96758.68
# PAYS : IRN
# Moyenne: 5832.6555007
# Medianne: 4255.57635
# Minimal: 441.56308
# Maximal: 49133.04
# PAYS : IRQ
# Moyenne: 1705.5123434000002
# Medianne: 1355.9865
# Minimal: 185.81454
# Maximal: 13830.766
# PAYS : ISL
# Moyenne: 26888.511518
# Medianne: 22767.718
# Minimal: 5191.9683
# Maximal: 160645.27
# PAYS : ISR
# Moyenne: 11100.318136899998
# Medianne: 8684.4835
# Minimal: 142.35043
# Maximal: 64825.383
# PAYS : ITA
# Moyenne: 14925.214921999997
# Medianne: 12896.164499999999
# Minimal: 1103.5525
# Maximal: 72745.47
# PAYS : JOR
# Moyenne: 3048.6309757
# Medianne: 2408.25465
# Minimal: 624.13184
# Maximal: 15614.141
# PAYS : JPN
# Moyenne: 17432.961184000003
# Medianne: 15071.5125
# Minimal: 1224.3405
# Maximal: 85569.336
# PAYS : KAZ
# Moyenne: 2239.1497999999997
# Medianne: 1936.5536
# Minimal: 597.11774
# Maximal: 8973.289
# PAYS : KEN
# Moyenne: 519.3200320000001
# Medianne: 450.06646
# Minimal: 96.68363
# Maximal: 2022.7759
# PAYS : KGZ
# Moyenne: 1773.2192169000004
# Medianne: 1463.5225
# Minimal: 221.00069
# Maximal: 8330.075
# PAYS : KHM
# Moyenne: 1486.3402467
# Medianne: 1220.8944999999999
# Minimal: 345.87497
# Maximal: 7375.561
# PAYS : KOR
# Moyenne: 15227.56944532
# Medianne: 12832.733
# Minimal: 17.317732
# Maximal: 76620.18
# PAYS : XKX
# Moyenne: 2176.2690352
# Medianne: 1835.0265
# Minimal: 437.8937
# Maximal: 7609.576
# PAYS : LAO
# Moyenne: 1003.4073528999995
# Medianne: 769.20292
# Minimal: 190.1414
# Maximal: 7154.5903
# PAYS : LBR
# Moyenne: 615.0072967799999
# Medianne: 479.01052
# Minimal: 37.782673
# Maximal: 4287.2
# PAYS : LKA
# Moyenne: 1877.9402439000003
# Medianne: 1325.6432
# Minimal: 363.08295
# Maximal: 17064.393
# PAYS : LTU
# Moyenne: 6641.247634343435
# Medianne: 5504.883
# Minimal: 566.3453
# Maximal: 38836.53
# PAYS : LUX
# Moyenne: 25217.562681000003
# Medianne: 22100.467
# Minimal: 5780.8374
# Maximal: 114823.68
# PAYS : LVA
# Moyenne: 6764.4745705000005
# Medianne: 5544.9017
# Minimal: 609.16125
# Maximal: 35658.387
# PAYS : MAR
# Moyenne: 2337.6006008999993
# Medianne: 1683.9353
# Minimal: 353.8489
# Maximal: 19593.357
# PAYS : MDA
# Moyenne: 2149.1713989000004
# Medianne: 1815.4202500000001
# Minimal: 402.171
# Maximal: 9223.797
# PAYS : MDG
# Moyenne: 345.2370736300001
# Medianne: 240.376565
# Minimal: 29.411367
# Maximal: 3164.7986
# PAYS : MEX
# Moyenne: 3885.830276540001
# Medianne: 2445.0681999999997
# Minimal: 68.490974
# Maximal: 44504.965
# PAYS : MKD
# Moyenne: 4599.396322299999
# Medianne: 3423.7389000000003
# Minimal: 559.1796
# Maximal: 26146.582
# PAYS : MLI
# Moyenne: 681.0750385400002
# Medianne: 545.44328
# Minimal: 122.693474
# Maximal: 2958.875
# PAYS : MNE
# Moyenne: 6547.899125
# Medianne: 5736.9917000000005
# Minimal: 1344.2195
# Maximal: 27919.86
# PAYS : MNG
# Moyenne: 2338.0874237
# Medianne: 1840.92345
# Minimal: 439.73892
# Maximal: 13784.397
# PAYS : MOZ
# Moyenne: 692.4805005999999
# Medianne: 472.04726000000005
# Minimal: 42.58384
# Maximal: 8547.452
# PAYS : MRT
# Moyenne: 1798.6090834000001
# Medianne: 1345.58075
# Minimal: 186.732
# Maximal: 13564.795
# PAYS : MWI
# Moyenne: 914.2654023999999
# Medianne: 613.0147
# Minimal: 115.63248
# Maximal: 9896.588
# PAYS : MYS
# Moyenne: 6006.342358999998
# Medianne: 4020.3568999999998
# Minimal: 589.0876
# Maximal: 50453.715
# PAYS : NER
# Moyenne: 650.1293531999999
# Medianne: 475.672765
# Minimal: 137.39531
# Maximal: 5096.2134
# PAYS : NGA
# Moyenne: 691.8553629099999
# Medianne: 464.91064
# Minimal: 51.04976
# Maximal: 6711.4663
# PAYS : NIC
# Moyenne: 2519.3332620300002
# Medianne: 1725.82735
# Minimal: 53.809303
# Maximal: 24727.162
# PAYS : NLD
# Moyenne: 17728.641150999996
# Medianne: 15211.8275
# Minimal: 2558.8208
# Maximal: 97551.0
# PAYS : NOR
# Moyenne: 22483.375020000003
# Medianne: 19719.8685
# Minimal: 3520.2615
# Maximal: 120354.22
# PAYS : NPL
# Moyenne: 914.3916509
# Medianne: 738.83415
# Minimal: 192.23878
# Maximal: 4825.275
# PAYS : PAK
# Moyenne: 887.8392791000001
# Medianne: 720.1007
# Minimal: 275.18982
# Maximal: 5151.582
# PAYS : PAN
# Moyenne: 5135.1393761
# Medianne: 3062.47245
# Minimal: 210.56883
# Maximal: 55466.152
# PAYS : PER
# Moyenne: 3330.5333487
# Medianne: 2265.494
# Minimal: 172.70412
# Maximal: 30853.23
# PAYS : PHL
# Moyenne: 1474.0628559000002
# Medianne: 994.2310500000001
# Minimal: 213.1265
# Maximal: 11498.612
# PAYS : POL
# Moyenne: 5741.720225
# Medianne: 4817.4492
# Minimal: 655.2539
# Maximal: 31375.277
# PAYS : PRT
# Moyenne: 10098.675365999996
# Medianne: 7914.2046
# Minimal: 893.6988
# Maximal: 58639.793
# PAYS : PRY
# Moyenne: 3278.0809654000004
# Medianne: 1981.11155
# Minimal: 114.11741
# Maximal: 43296.383
# PAYS : ROU
# Moyenne: 3318.3371888
# Medianne: 2776.15435
# Minimal: 199.77019
# Maximal: 17002.113
# PAYS : RUS
# Moyenne: 7156.770709
# Medianne: 5083.8087
# Minimal: 989.4186
# Maximal: 51952.52
# PAYS : SDN
# Moyenne: 1085.3470589999995
# Medianne: 890.26225
# Minimal: 148.52118
# Maximal: 5336.524
# PAYS : SLV
# Moyenne: 2855.2248092
# Medianne: 1880.6225
# Minimal: 178.57782
# Maximal: 25879.79
# PAYS : SRB
# Moyenne: 4879.750851600001
# Medianne: 4261.65185
# Minimal: 953.28656
# Maximal: 17643.387
# PAYS : SVK
# Moyenne: 6096.579894399999
# Medianne: 5713.6087
# Minimal: 791.46204
# Maximal: 22350.904
# PAYS : SVN
# Moyenne: 12106.007475000002
# Medianne: 11127.3775
# Minimal: 2814.953
# Maximal: 39012.44
# PAYS : SWE
# Moyenne: 16184.222706999994
# Medianne: 14570.083999999999
# Minimal: 2284.4329
# Maximal: 64328.734
# PAYS : SWZ
# Moyenne: 530.28382752
# Medianne: 351.08335999999997
# Minimal: 35.930096
# Maximal: 3924.228
# PAYS : SYR
# Moyenne: 685.8174949
# Medianne: 525.26077
# Minimal: 143.18066
# Maximal: 4284.0645
# PAYS : THA
# Moyenne: 2743.7126405000004
# Medianne: 1728.92625
# Minimal: 257.64386
# Maximal: 18950.998
# PAYS : TJK
# Moyenne: 2069.852224
# Medianne: 1780.0943
# Minimal: 436.13986
# Maximal: 9453.971
# PAYS : TLS
# Moyenne: 727.6103946000003
# Medianne: 578.6589650000001
# Minimal: 204.18102
# Maximal: 4460.1562
# PAYS : TUR
# Moyenne: 6050.465331
# Medianne: 4627.2935
# Minimal: 439.05606
# Maximal: 42896.71
# PAYS : TZA
# Moyenne: 588.7669863
# Medianne: 451.22856
# Minimal: 84.04393
# Maximal: 3942.9866
# PAYS : UGA
# Moyenne: 987.2062888999999
# Medianne: 680.852905
# Minimal: 121.17981
# Maximal: 8694.983
# PAYS : UKR
# Moyenne: 3349.3883065
# Medianne: 2972.5064
# Minimal: 942.38495
# Maximal: 11564.171
# PAYS : URY
# Moyenne: 5290.784920199999
# Medianne: 3570.22255
# Minimal: 472.62976
# Maximal: 46821.887
# PAYS : USA
# Moyenne: 25503.58166099999
# Medianne: 19178.161999999997
# Minimal: 663.4761
# Maximal: 176928.55
# PAYS : VEN
# Moyenne: 3167.1477239
# Medianne: 2293.9416499999998
# Minimal: 171.89282
# Maximal: 24857.973
# PAYS : VNM
# Moyenne: 1377.7739658
# Medianne: 1040.4284
# Minimal: 234.26695
# Maximal: 9522.466
# PAYS : PSE
# Moyenne: 1114.0985142
# Medianne: 873.9127149999999
# Minimal: 195.2899
# Maximal: 6343.8755
# PAYS : YEM
# Moyenne: 1042.6358698
# Medianne: 792.49885
# Minimal: 162.95131
# Maximal: 9050.4375
# PAYS : ZAF
# Moyenne: 5617.904879630001
# Medianne: 2065.8659
# Minimal: 60.490383
# Maximal: 82408.55
# PAYS : COD
# Moyenne: 276.01604415
# Medianne: 186.92406
# Minimal: 29.364283
# Maximal: 2243.1226

# %% [markdown]
# Suite à cette analyse on peut voir que l'analyse par centiles est très efficace car elle permet de faire une analyse pointu des données au % de la population près et ainsi constater des différences entre chaque catégorie social de la population.

# %% [markdown]
# ## Mission 2
#
# Montrez la diversité des pays en termes de distribution de revenus à l'aide d'un graphique.
# - Celui-ci représentera le revenu moyen (axe des ordonnées, sur une échelle logarithmique) de chacune des classes de revenus (axe des abscisses) pour 5 à 10 pays que vous aurez choisis pour montrer la diversité des cas.
# - Représentez la courbe de Lorenz de chacun des pays choisis.
# - Pour chacun de ces pays, représentez l'évolution de l'indice de Gini au fil des ans.
# - Classez les pays par indice de Gini. Donnez la moyenne, les 5 pays ayant l'indice de Gini le plus élevé et les 5 pays ayant l'indice de Gini le plus faible. En quelle position se trouve la France ?

# %% [markdown]
# ### Choix des pays

# %%
def lorenz(dataset):
    print('Courbes de Lorenz et Indices de Gini:')
    
    for e in dataset.select_dtypes(include='number').columns:
        
        lorenz = np.cumsum(dataset[e].sort_values()) / dataset[e].sum()
        lorenz = np.append([0],lorenz)
        n = len(dataset[e])
        #plt.axes().axis('equal')
        xaxis = np.linspace(0-1/n,1+1/n,n+1)
        AUC = (lorenz.sum() -lorenz[-1]/2 -lorenz[0]/2)/n 
        S = 0.5 - AUC
        gini = 2*S
        
        plt.figure()
        plt.plot(xaxis,lorenz)
        plt.plot([0.0, 1.0], [0.0, 1.0])
        plt.fill_between(xaxis,lorenz,xaxis,color='#f2f2f2')
        plt.title('Gini: '+str(gini.round(3)))
        plt.suptitle(e) 
        plt.savefig('courbe de lorenz_gini.png')

# %%
data
# Out:
#       Country  Year  Quantile      Income         GDP     Name  Population  \
# 0         ALB  2008         1   728.89795  7297.00000  Albania     2947314
# 1         ALB  2008         2   916.66235  7297.00000  Albania     2947314
# 2         ALB  2008         3  1010.91600  7297.00000  Albania     2947314
# 3         ALB  2008         4  1086.90780  7297.00000  Albania     2947314
# 4         ALB  2008         5  1132.69970  7297.00000  Albania     2947314
# ...       ...   ...       ...         ...         ...      ...         ...
# 11494     COD  2008        96   810.62330   303.19305    Congo    60411195
# 11495     COD  2008        97   911.78340   303.19305    Congo    60411195
# 11496     COD  2008        98  1057.80740   303.19305    Congo    60411195
# 11497     COD  2008        99  1286.60290   303.19305    Congo    60411195
# 11498     COD  2008       100  2243.12260   303.19305    Congo    60411195
#
#        %_pop_total
# 0         0.047685
# 1         0.047685
# 2         0.047685
# 3         0.047685
# 4         0.047685
# ...            ...
# 11494     0.977402
# 11495     0.977402
# 11496     0.977402
# 11497     0.977402
# 11498     0.977402
#
# [11499 rows x 8 columns]

# %%
# Choix des pays
france = data.loc[data['Country'] == 'FRA'][['Income', 'Quantile']]
bresil = data.loc[data['Country'] == 'BRA'][['Income', 'Quantile']]
canada = data.loc[data['Country'] == 'CAN'][['Income', 'Quantile']]
bangladesh = data.loc[data['Country'] == 'BGD'][['Income', 'Quantile']]
indonesia = data.loc[data['Country'] == 'IDN'][['Income', 'Quantile']]

sns.lineplot(data=france, x='Quantile', y='Income')
# Out:
# <AxesSubplot:xlabel='Quantile', ylabel='Income'>

# %%
lorenz(france)
# Out:
# Courbes de Lorenz et Indices de Gini:

# %%
sns.lineplot(data=bresil, x='Quantile', y='Income')
# Out:
# <AxesSubplot:xlabel='Quantile', ylabel='Income'>

# %%
lorenz(bresil)
# Out:
# Courbes de Lorenz et Indices de Gini:

# %%
sns.lineplot(data=canada, x='Quantile', y='Income')
# Out:
# <AxesSubplot:xlabel='Quantile', ylabel='Income'>

# %%
lorenz(canada)
# Out:
# Courbes de Lorenz et Indices de Gini:

# %%
sns.lineplot(data=bangladesh, x='Quantile', y='Income')
# Out:
# <AxesSubplot:xlabel='Quantile', ylabel='Income'>

# %%
lorenz(bangladesh)
# Out:
# Courbes de Lorenz et Indices de Gini:

# %%
sns.lineplot(data=indonesia, x='Quantile', y='Income')
# Out:
# <AxesSubplot:xlabel='Quantile', ylabel='Income'>

# %%
lorenz(indonesia)
# Out:
# Courbes de Lorenz et Indices de Gini:

# %% [markdown]
# ## Mission 3
# Dans l'état actuel, nous avons à disposition deux des trois variables explicatives souhaitées :
# - le revenu moyen du pays
# - l'indice de Gini du pays
# Il nous manque donc, pour un individu , la classe de revenu de ses parents.
#
# ...
